# %%
import numpy as np
import numpy.random as randn
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
from matplotlib import rcParams

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

plt.plot(x,y)

# %%
address = 'mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

#mpgx = cars['car_names']
#mpgy = cars['mpg']
#plt.plot(mpgx, mpgy)
mpg = cars['mpg']
mpg.plot()

# %%
df = cars[['mpg','cyl','hp','drat']]
df.plot()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
mpg.plot(kind='bar')

# %%
mpg.plot(kind='barh')

# %%
piedata = [1,2,3,4,0,5]

# %%
plt.pie(piedata)
plt.show()

# %%
plt.pie(piedata)
plt.savefig('piechart.png')

# %% [markdown]
# Plotting charts using object oriented approach
